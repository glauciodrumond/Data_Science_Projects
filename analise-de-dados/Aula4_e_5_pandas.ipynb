# %% [markdown]
# <a href="https://colab.research.google.com/github/glauciodrumond/Data_Science_Projects/blob/master/analise-de-dados/Aula4_e_5_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Trabalhando com Planilhas do Excel**

# %%
#Importando a biblioteca
import pandas as pd

# %%
#Leitura dos arquivos
df1 = pd.read_excel("https://github.com/glauciodrumond/unimed-datascience/blob/main/analise-de-dados/datasets/Aracaju.xlsx?raw=true")
df2 = pd.read_excel("https://github.com/glauciodrumond/unimed-datascience/blob/main/analise-de-dados/datasets/Fortaleza.xlsx?raw=true")
df3 = pd.read_excel("https://github.com/glauciodrumond/unimed-datascience/blob/main/analise-de-dados/datasets/Natal.xlsx?raw=true")
df4 = pd.read_excel("https://github.com/glauciodrumond/unimed-datascience/blob/main/analise-de-dados/datasets/Recife.xlsx?raw=true")
df5 = pd.read_excel("https://github.com/glauciodrumond/unimed-datascience/blob/main/analise-de-dados/datasets/Salvador.xlsx?raw=true")

# %%
df5.head()
# Out:
#      Cidade       Data  Vendas  LojaID  Qtde
# 0  Salvador 2018-01-01   31.06    1037     3
# 1  Salvador 2018-01-01   19.02    1034     3
# 2  Salvador 2019-02-10  173.59    1035     3
# 3  Salvador 2019-02-10  176.34    1037     3
# 4  Salvador 2019-02-14   19.47    1037     3

# %%
#juntando todos os arquivos
df = pd.concat([df1,df2,df3,df4,df5])

# %%
#Exibindo as 5 primeiras linhas
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
#Exibindo as 5 últimas linhas
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 164      Natal 2019-01-02    6.59    1035     1
# 61    Salvador 2019-01-01    4.54    1036     3
# 97      Recife 2019-01-01  153.04     983     4
# 203   Salvador 2019-01-02   37.75    1035     2
# 59   Fortaleza 2019-01-01    6.31    1002     3

# %%
#Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
#Alterando o tipo de dado da coluna LojaID
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %% [markdown]
# **Tratando valores faltantes**

# %%
#Consultando linhas com valores faltantes
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
#Substituindo os valores nulos pela média
df["Vendas"].fillna(df["Vendas"].mean(), inplace=True)

# %%
df["Vendas"].mean()
# Out:
# 122.61180089485458

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 124     Recife 2019-03-02   47.98    983     7
# 15      Recife 2019-01-01    7.45    981     2
# 3      Aracaju 2018-01-01    3.01   1521     7
# 136  Fortaleza 2019-03-02   39.09    982     4
# 124      Natal 2019-01-02   44.82   1034     3
# 69    Salvador 2019-01-01   14.79   1035     1
# 100      Natal 2019-01-02  190.97   1036     2
# 99    Salvador 2019-01-01   40.38   1037     1
# 107   Salvador 2019-01-01   14.70   1035     1
# 68    Salvador 2019-01-01  162.35   1037     3
# 195      Natal 2019-01-02   44.89   1036     3
# 106    Aracaju 2018-01-01   16.32   1520     7
# 228   Salvador 2019-01-02    6.87   1037     3
# 141     Recife 2019-03-02  182.75    983     8
# 215      Natal 2019-01-02  203.84   1036     1

# %%
#Substituindo os valores nulos por zero
df["Vendas"].fillna(0, inplace=True)

# %%
#Apagando as linhas com valores nulos
df.dropna(inplace=True)

# %%
#Apagando as linhas com valores nulos com base apenas em 1 coluna
df.dropna(subset=["Vendas"], inplace=True)

# %%
#Removendo linhas que estejam com valores faltantes em todas as colunas
df.dropna(how="all", inplace=True)

# %% [markdown]
# **Criando colunas novas**

# %%
#Criando a coluna de receita
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df["Receita/Vendas"] = df["Receita"] / df["Vendas"]

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00             1.0
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26             6.0
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55             1.0
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07             7.0
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08             8.0

# %%
#Retornando a maior receita
df["Receita"].max()
# Out:
# 3544.0

# %%
#Retornando a menor receita
df["Receita"].min()
# Out:
# 3.34

# %%
#nlargest
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0             4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0             4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0             4.0

# %%
#nsamllest
df.nsmallest(3, "Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34             1.0
# 65    Recife 2019-01-01    4.01    981     1     4.01             1.0
# 92     Natal 2019-01-02    4.57   1035     1     4.57             1.0

# %%
#Agrupamento por cidade
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
#Ordenando o conjunto de dados
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0             4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0             4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0             4.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0             4.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0             4.0
# 38  Natal 2018-02-25   828.0    852     4   3312.0             4.0
# 10  Natal 2018-10-27   828.0    852     4   3312.0             4.0
# 69  Natal 2019-03-24   817.0    852     4   3268.0             4.0
# 62  Natal 2018-02-10   793.0    854     4   3172.0             4.0
# 52  Natal 2018-04-27   778.0    854     4   3112.0             4.0

# %% [markdown]
# #**Trabalhando com datas**

# %%
#Trasnformando a coluna de data em tipo inteiro
df["Data"] = df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
#Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade             object
# Data                int64
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# Receita/Vendas    float64
# dtype: object

# %%
#Transformando coluna de data em data
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade                    object
# Data              datetime64[ns]
# Vendas                   float64
# LojaID                    object
# Qtde                       int64
# Receita                  float64
# Receita/Vendas           float64
# dtype: object

# %%
#Agrupamento por ano
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
#Criando uma nova coluna com o ano
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 98      Recife 2019-01-01  137.34    981     8  1098.72             8.0
# 46     Aracaju 2018-01-01   41.42   1522     2    82.84             2.0
# 135   Salvador 2019-03-02    9.95   1037     3    29.85             3.0
# 16   Fortaleza 2019-01-01   97.32   1002     5   486.60             5.0
# 64       Natal 2019-02-22  704.00    853     4  2816.00             4.0
#
#      Ano_Venda
# 98        2019
# 46        2018
# 135       2019
# 16        2019
# 64        2019

# %%
#Extraindo o mês e o dia
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 66   Fortaleza 2019-01-01   35.11   1005     6   210.66             6.0
# 68    Salvador 2019-01-01  162.35   1037     3   487.05             3.0
# 234   Salvador 2019-01-03   48.39   1035     2    96.78             2.0
# 17       Natal 2018-02-18  276.00    854     3   828.00             3.0
# 113     Recife 2019-03-02   38.63    980     2    77.26             2.0
#
#      Ano_Venda  mes_venda  dia_venda
# 66        2019          1          1
# 68        2019          1          1
# 234       2019          1          3
# 17        2018          2         18
# 113       2019          3          2

# %%
#Retornando a data mais antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
#Calculando a diferença de dias
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 184  Salvador 2019-01-02  167.16   1037     1   167.16             1.0
# 134     Natal 2019-01-02  125.90   1036     1   125.90             1.0
# 166  Salvador 2019-01-02  111.72   1035     3   335.16             3.0
# 3       Natal 2019-01-07  271.00    854     3   813.00             3.0
# 103   Aracaju 2018-01-01   12.62   1522     3    37.86             3.0
#
#      Ano_Venda  mes_venda  dia_venda diferenca_dias
# 184       2019          1          2       366 days
# 134       2019          1          2       366 days
# 166       2019          1          2       366 days
# 3         2019          1          7       371 days
# 103       2018          1          1         0 days

# %%
#Criando a coluna de trimestre
df["trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 73   Fortaleza 2019-01-01    3.10   1003     5    15.50             5.0
# 30    Salvador 2019-01-01   47.96   1034     2    95.92             2.0
# 23      Recife 2019-01-01   37.51    982     2    75.02             2.0
# 26    Salvador 2019-01-01  183.45   1036     3   550.35             3.0
# 171   Salvador 2019-01-02  136.45   1035     3   409.35             3.0
#
#      Ano_Venda  mes_venda  dia_venda diferenca_dias  trimestre_venda
# 73        2019          1          1       365 days                1
# 30        2019          1          1       365 days                1
# 23        2019          1          1       365 days                1
# 26        2019          1          1       365 days                1
# 171       2019          1          2       366 days                1

# %%
#Filtrando as vendas de 2019 do mês de março
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 138     Recife 2019-03-02  150.38    983     6   902.28             6.0
# 112  Fortaleza 2019-03-02  133.59    982     1   133.59             1.0
# 110  Fortaleza 2019-03-02   51.98    983     6   311.88             6.0
# 125  Fortaleza 2019-03-02   37.60    983     4   150.40             4.0
# 110     Recife 2019-03-02   51.98    983     6   311.88             6.0
# 110   Salvador 2019-03-02  185.93   1036     3   557.79             3.0
# 123   Salvador 2019-03-02  127.45   1036     3   382.35             3.0
# 75       Natal 2019-03-30  706.00    854     2  1412.00             2.0
# 139     Recife 2019-03-02  141.16    980     7   988.12             7.0
# 138   Salvador 2019-03-02  212.03   1037     3   636.09             3.0
# 128  Fortaleza 2019-03-02   38.70    982     4   154.80             4.0
# 130   Salvador 2019-03-02   59.78   1036     1    59.78             1.0
# ...
